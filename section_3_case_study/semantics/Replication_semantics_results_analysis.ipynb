# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Project_AI
# !ls
# Out:
# /content/drive/MyDrive/Project_AI
#  200_sampled_per_run.csv   log.csv					 tf-cf-0.9-bert-0.98.csv
#  bert_output.csv	   outputs					 training_args.json
#  best_model		  'Project_Reproduction_NLP_Amarilda Koka'	 training_output.csv
#  case_study_examples.csv   README.md					 train_log.txt
#  checkpoints		   Reevaluating-NLP-Adversarial-Examples
#  last_model		   Replication-NLP-Adversarial-Examples-master

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Project_AI/Replication-NLP-Adversarial-Examples-master/section_3_case_study/semantics/semantics_results.csv', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#                                          Input.text1  \
# 0   clooney directs this film always keeping the ...
# 1   clooney directs this film always keeping the ...
# 2   clooney directs this film always keeping the ...
# 3   clooney directs this film always keeping the ...
# 4   clooney directs this film always keeping the ...
#
#                                          Input.text2  \
# 0   clooney directs this film ever remained the c...
# 1   clooney directs this film ever remained the c...
# 2   clooney directs this film ever remained the c...
# 3   clooney directs this film ever remained the c...
# 4   clooney directs this film ever remained the c...
#
#   Answer.semantic-similarity.label Input.run_type Input.dataset  \
# 0                Strongly Disagree            jin  movie_review
# 1                Strongly Disagree            jin  movie_review
# 2                Strongly Disagree            jin  movie_review
# ...

# %%
label_map = {'Strongly Agree': 5, 'Agree': 4, 'Not sure': 3, 'Disagree': 2, 'Strongly Disagree': 1}
df['label'] = df['Answer.semantic-similarity.label'].str.strip().map(lambda s: label_map.get(s))

# %%
df['label'].mean()
# Out:
# 2.8997668997668997

# %%
df.columns
# Out:
# Index(['Input.text1', 'Input.text2', 'Answer.semantic-similarity.label',
#        'Input.run_type', 'Input.dataset', 'Answer.semantic-similarity.label.1',
#        'Input.run_type.1', 'Input.dataset.1', 'Title', 'Description', 'label'],
#       dtype='object')

# %%
df.groupby('Input.run_type')['label'].mean()
# Out:
# Input.run_type
# alzantot    2.382022
# jin         3.035294
# Name: label, dtype: float64

# %%
df['Input.dataset'].unique()
# Out:
# array(['movie_review', 'imdb', 'yelp_polarity'], dtype=object)

# %%
df.groupby(['Input.run_type', 'Input.dataset'])['label'].mean()
# Out:
# Input.run_type  Input.dataset
# alzantot        imdb             2.382022
# jin             imdb             3.476190
#                 movie_review     3.035156
#                 yelp_polarity    2.888889
# Name: label, dtype: float64
